# %%
# !python main.py
# Out:
#  Step 1: Training Model...
# Training complete. Metrics saved.
#
#  Step 2: Generating Forecast...
# Training complete. Metrics saved.
# Forecast saved.
#
#  Step 3: Generating Insights...
# Insights saved to Insights.json
#
#  Pipeline completed successfully!

# %%
# !python evaluation/final_model_accuracy.py
# Out:
# FINAL MODEL ACCURACY (HistGradientRegressor)
#
# sales_units Accuracy: 95.17%
# revenue Accuracy: 98.75%
# new_customers Accuracy: 94.75%
# cost Accuracy: 95.76%
# expenses Accuracy: 93.07%
#
# Overall Final Accuracy: 95.5 %
